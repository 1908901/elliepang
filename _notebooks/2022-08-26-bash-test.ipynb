# %%
echo "Using conditional statement to create a project directory and project"

# Variable section
export project_dir=$HOME/vscode  # change vscode to different name to test git clone
export project=$project_dir/APCSP  # change APCSP to name of project from git clone
export project_repo="https://github.com/nighthawkcoders/APCSP.git"  # change to project of choice

cd ~    # start in home directory

# Conditional block to make a project directory
if [ ! -d $project_dir ]
then 
    echo "Directory $project_dir does not exists... makinng directory $project_dir"
    mkdir -p $project_dir
fi
echo "Directory $project_dir exists." 

# Conditional block to git clone a project from project_repo
if [ ! -d $project ]
then
    echo "Directory $project does not exists... cloning $project_repo"
    cd $project_dir
    git clone $project_repo
    cd ~
fi
echo "Directory $project exists." 

# You must run cells above to define variable and project

echo "Navigate to project, then navigate to area wwhere files were cloned"
cd $project
pwd

echo ""
echo "list top level or root of files with project pulled from github"
ls

echo ""
echo "list again with hidden files pulled from github"
ls -a   # hidden files flag, many shell commands have flags

echo ""
echo "list all files in long format"
ls -al   # all files and long listing

# You must run cells above to define variable and project

echo "Look for posts"
export posts=$project/_posts  # _posts inside project
cd $posts  # this should exist per fastpages
pwd  # present working directory
ls -l  # list posts

# You must run cells above to define variable and project

echo "Look for notebooks"
export notebooks=$project/_notebooks  # _notebooks is inside project
cd $notebooks   # this should exist per fastpages
pwd  # present working directory
ls -l  # list notebooks

# You must run cells above to define notebooks location

echo "Look for images in notebooks, print working directory, list files"
cd $notebooks/images  # this should exist per fastpages
pwd
ls -l
# Out:
# Using conditional statement to create a project directory and project
# Directory /home/elliepang007/vscode exists.
# Directory /home/elliepang007/vscode/APCSP exists.
# Navigate to project, then navigate to area wwhere files were cloned
# /home/elliepang007/vscode/APCSP
#
# list top level or root of files with project pulled from github
# Gemfile    _action_files    _layouts    _posts  docker-compose.yml
# LICENSE    _config.yml      _notebooks  _sass   images
# Makefile   _fastpages_docs  _pages      _word   index.html
# README.md  _includes        _plugins    assets  python
#
# list again with hidden files pulled from github
# .                   .gitignore  _action_files    _pages    docker-compose.yml
# ..                  .vscode     _config.yml      _plugins  images
# .devcontainer.json  Gemfile     _fastpages_docs  _posts    index.html
# .git                LICENSE     _includes        _sass     python
# .gitattributes      Makefile    _layouts         _word
# .github             README.md   _notebooks       assets
#
# list all files in long format
# total 40
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 .
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 ..
# -rw-r--r-- 1 elliepang007 elliepang007   420 Aug 18 19:45 .devcontainer.json
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 25 11:32 .git
# -rw-r--r-- 1 elliepang007 elliepang007    84 Aug 18 19:45 .gitattributes
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 .github
# -rw-r--r-- 1 elliepang007 elliepang007   917 Aug 18 19:45 .gitignore
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 22 11:21 .vscode
# -rwxr-xr-x 1 elliepang007 elliepang007  1304 Aug 18 19:45 Gemfile
# -rw-r--r-- 1 elliepang007 elliepang007 11351 Aug 18 19:45 LICENSE
# -rwxr-xr-x 1 elliepang007 elliepang007  1422 Aug 18 19:45 Makefile
# -rwxr-xr-x 1 elliepang007 elliepang007  3614 Aug 18 19:45 README.md
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 _action_files
# -rw-r--r-- 1 elliepang007 elliepang007  3716 Aug 18 19:45 _config.yml
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 _fastpages_docs
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 _includes
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 _layouts
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 25 11:30 _notebooks
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 22 11:21 _pages
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 _plugins
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 22 22:20 _posts
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 _sass
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 _word
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 assets
# -rwxr-xr-x 1 elliepang007 elliepang007  1136 Aug 18 19:45 docker-compose.yml
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 22 11:21 images
# -rw-r--r-- 1 elliepang007 elliepang007  1061 Aug 18 19:45 index.html
# drwxr-xr-x 1 elliepang007 elliepang007   512 Aug 18 19:45 python
# Look for posts
# /home/elliepang007/vscode/APCSP/_posts
# total 224
# -rw-r--r-- 1 elliepang007 elliepang007 21306 Aug 18 19:45 2022-06-01-TT160-deploy.md
# -rw-r--r-- 1 elliepang007 elliepang007  5861 Aug 18 19:45 2022-07-07-PBL-binary.md
# -rw-r--r-- 1 elliepang007 elliepang007  3085 Aug 18 19:45 2022-07-08-PBL-grade_calc.md
# -rw-r--r-- 1 elliepang007 elliepang007  3698 Aug 18 19:45 2022-07-08-PBL-graph.md
# -rw-r--r-- 1 elliepang007 elliepang007  5729 Aug 18 19:45 2022-07-08-PBL-life.md
# -rw-r--r-- 1 elliepang007 elliepang007 14387 Aug 18 19:45 2022-07-08-PBL-snake.md
# -rw-r--r-- 1 elliepang007 elliepang007   334 Aug 18 19:45 2022-07-10-PBL-database.md
# -rw-r--r-- 1 elliepang007 elliepang007  2908 Aug 18 19:45 2022-07-10-PBL-jokes.md
# -rw-r--r-- 1 elliepang007 elliepang007  4046 Aug 18 19:45 2022-07-10-PBL-rapidapi.md
# -rw-r--r-- 1 elliepang007 elliepang007  6685 Aug 18 19:45 2022-07-19-PBL-calculator.md
# -rw-r--r-- 1 elliepang007 elliepang007 23325 Aug 18 19:45 2022-07-25-CSP-workshop.md
# -rw-r--r-- 1 elliepang007 elliepang007  2333 Aug 18 19:45 2022-08-15-TP000-student_score_history.md
# -rw-r--r-- 1 elliepang007 elliepang007  4363 Aug 18 19:45 2022-08-15-TP100-pseudo_code.md
# -rw-r--r-- 1 elliepang007 elliepang007  7968 Aug 18 19:45 2022-08-15-TR100-tool_setup.md
# -rw-r--r-- 1 elliepang007 elliepang007 15026 Aug 18 19:45 2022-08-15-TT100-tools.md
# -rw-r--r-- 1 elliepang007 elliepang007  5590 Aug 22 11:21 2022-08-15-TT101-vscode-wsl.md
